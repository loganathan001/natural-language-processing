# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
movie_lines_f = pd.read_csv('cmc_data/movie_conversations.txt', sep='+++$+++', engine='python')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-208d52edbfac> in <module>
# ----> 1 movie_lines_f = pd.read_csv('cmc_data/movie_conversations.txt', sep='+++$+++', engine='python')
#
# ...
